# %%
import pandas as pd
import numpy as np

# %%
refs=pd.read_csv('reference.csv')
refs.head()
# Out:
#    Unnamed: 0                            healthCode  audio_audio.m4a  \
# 0           0  639e8a78-3631-4231-bda1-c911c1b169e5          5404521
# 1           1  52fe366a-2a9f-4260-9fb1-0fbc637a6cf4          5410381
# 2           2  52fe366a-2a9f-4260-9fb1-0fbc637a6cf4          5773552
# 3           3  52fe366a-2a9f-4260-9fb1-0fbc637a6cf4          5805736
# 4           4  67bdd316-26fc-4fc7-8431-bf9f41a649dd          5390859
#
#                          medTimepoint   age  diagnosis-year  gender  \
# 0  I don't take Parkinson medications  24.0             NaN    Male
# 1  I don't take Parkinson medications  38.0             NaN  Female
# 2  I don't take Parkinson medications  38.0             NaN  Female
# 3  I don't take Parkinson medications  38.0             NaN  Female
# 4  I don't take Parkinson medications  32.0             NaN    Male
#
#   healthcare-provider home-usage medical-usage medical-usage-yesterday  \
# ...
