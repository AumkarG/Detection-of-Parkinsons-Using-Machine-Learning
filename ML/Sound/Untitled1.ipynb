# %%
import librosa
audio_path = 'D:\Downloads\Mpower data\mpwav 6500\mpw1\\5388081.wav'
x , sr = librosa.load(audio_path)
print(type(x), type(sr))
# Out:
# <class 'numpy.ndarray'> <class 'int'>

# %%
x
# Out:
# array([-0.00051527, -0.00020099,  0.00047635, ...,  0.06725913,
#         0.06380255,  0.06802113], dtype=float32)

# %%
import IPython.display as ipd
ipd.Audio(audio_path)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#display waveform
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
#display Spectrogram
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz') 
#If to pring log of frequencies  
#librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %%
plt.plot(x)

# %%
mfccs = librosa.feature.mfcc(x, sr=sr)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
# Out:
# (20, 434)

# %%
mfccs.shape
# Out:
# (20, 434)

# %%
mfccs
# Out:
# array([[-5.1489075e+02, -5.1020114e+02, -4.7230991e+02, ...,
#         -3.2996161e+02, -3.0607675e+02, -2.9579843e+02],
#        [ 6.2314529e+01,  6.3199768e+01,  2.1338099e+01, ...,
#          1.1871361e+02,  1.5280231e+02,  1.7096945e+02],
#        [-1.0431784e+01, -1.2920446e+01,  4.4484649e+00, ...,
#          6.8483925e+00,  3.2276512e+01,  4.1872246e+01],
#        ...,
#        [ 7.5974268e-01, -5.2020969e+00, -2.1489205e+00, ...,
#         -3.4568334e+00,  2.9400482e+00,  3.3566945e+00],
#        [-1.2345181e+00, -5.9455395e+00, -9.9868717e+00, ...,
#         -1.7324135e+01, -1.3849868e+01, -1.5603803e+01],
#        [ 4.7842062e-01, -9.6545267e-01, -6.3733363e+00, ...,
#         -1.2865625e+01, -3.8936164e+00, -2.2249000e+00]], dtype=float32)

# %%
spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)[0]
librosa.display.waveplot(x, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_rolloff), color='r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-84c2f7737596> in <module>
# ----> 1 spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)[0]
#       2 librosa.display.waveplot(x, sr=sr, alpha=0.4)
#       3 plt.plot(t, normalize(spectral_rolloff), color='r')
#
# NameError: name 'librosa' is not defined

# %%
mfccs = librosa.feature.mfcc(x, sr=sr)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9a7ee64fd739> in <module>
# ----> 1 mfccs = librosa.feature.mfcc(x, sr=sr)
#       2 print(mfccs.shape)
#       3 #Displaying  the MFCCs:
#       4 librosa.display.specshow(mfccs, sr=sr, x_axis='time')
#
# NameError: name 'librosa' is not defined
